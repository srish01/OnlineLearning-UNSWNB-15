# %% [markdown]
# # ABOUT

# %%
# !pip install -U scikit-multiflow
# Out:
# Requirement already up-to-date: scikit-multiflow in /usr/local/lib/python3.6/dist-packages (0.5.3)
# Requirement already satisfied, skipping upgrade: sortedcontainers>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from scikit-multiflow) (2.2.2)
# Requirement already satisfied, skipping upgrade: pandas>=0.25.3 in /usr/local/lib/python3.6/dist-packages (from scikit-multiflow) (1.0.5)
# Requirement already satisfied, skipping upgrade: scipy>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-multiflow) (1.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from scikit-multiflow) (1.18.5)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-multiflow) (3.2.2)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.20 in /usr/local/lib/python3.6/dist-packages (from scikit-multiflow) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.25.3->scikit-multiflow) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.25.3->scikit-multiflow) (2018.9)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.0.0->scikit-multiflow) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.0.0->scikit-multiflow) (1.2.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=2.0.0->scikit-multiflow) (2.4.7)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.20->scikit-multiflow) (0.16.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.25.3->scikit-multiflow) (1.15.0)

# %%
import numpy as np 
import scipy as sp
import pandas as pd 
from sklearn.feature_selection import mutual_info_classif
import matplotlib.pylab as plt
plt.style.use('ggplot')

from sklearn import preprocessing
from skmultiflow.trees import HoeffdingTreeClassifier, HoeffdingAdaptiveTreeClassifier
from skmultiflow.meta import OnlineBoostingClassifier, OzaBaggingClassifier, DynamicWeightedMajorityClassifier
from skmultiflow.meta import LearnPPNSEClassifier
from skmultiflow.data import DataStream
from skmultiflow.evaluation import EvaluatePrequential, EvaluateHoldout

from google.colab import drive, files

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def standardize_df(df): 
    for key in df.keys(): 
        if key != 'target': 
            df[key] = (df[key].values - df[key].values.mean())/df[key].values.std()
    return df

# %%
pretrain_size = 2000
batch_size = 1000
metrics = ['accuracy', 'f1', 'kappa']
data_path = '/content/drive/My Drive/Data/UNSWNB15/'
code_path = '/content/drive/My Drive/Colab Notebooks/Projects/TIS-IEEE-2020/'
output_path = code_path+'outputs/'
max_samples = 1000000

# %%
df_tr = pd.read_csv(data_path + 'UNSW_NB15_training-set.csv')
df_te = pd.read_csv(data_path + 'UNSW_NB15_testing-set.csv')

drop_cols = ['id', 'proto', 'service', 'state', 'attack_cat', 'is_sm_ips_ports']
# drop_cols = ['id', 'proto', 'service', 'state', 'attack_cat', 'label', 'is_sm_ips_ports']
# drop_cols = ['id', 'proto', 'service', 'state', 'attack_cat', 'label']

# binary
df_sub = df_tr.drop(drop_cols, axis = 1)
df_sub = df_sub.rename(columns={"label": "target"})


df_sub.head()
df_sub = standardize_df(df_sub)
df_sub = df_sub.sample(frac=1).reset_index(drop=True)

stream = DataStream(df_sub)

# %%
df_sub.head()
# Out:
#         dur     spkts     dpkts  ...  ct_src_ltm  ct_srv_dst  target
# 0 -0.209773 -0.133677 -0.172047  ...    1.086853    0.641377       1
# 1 -0.209774 -0.133677 -0.172047  ...    1.207024    0.734340       1
# 2  1.168926 -0.119066 -0.172047  ...    0.485997    0.176560       0
# 3 -0.209774 -0.133677 -0.172047  ...   -0.475371   -0.567147       1
# 4  0.130476  0.041650  0.880031  ...   -0.595543   -0.753074       1
#
# [5 rows x 39 columns]

# %%
mdl = HoeffdingTreeClassifier()
evaluator = EvaluatePrequential(show_plot=False, 
                                pretrain_size=pretrain_size, 
                                batch_size=batch_size, 
                                metrics=metrics, 
                                max_samples=max_samples,
                                output_file=output_path + 'output_ht.csv')
mdl = evaluator.evaluate(stream=stream, model=mdl)
# Out:
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 2000 sample(s).
# Evaluating...
#  #################### [100%] [81.68s]
# Processed samples: 176000
# Mean performance:
# M0 - Accuracy     : 0.9185
# M0 - Kappa        : 0.8038
# M0 - F1 score: 0.9424

# %%
mdl = HoeffdingAdaptiveTreeClassifier()
evaluator = EvaluatePrequential(show_plot=False, 
                                pretrain_size=pretrain_size, 
                                batch_size=batch_size, 
                                metrics=metrics, 
                                max_samples=max_samples,
                                output_file=output_path + 'output_hta.csv')
mdl = evaluator.evaluate(stream=stream, model=mdl)
# Out:
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 2000 sample(s).
# Evaluating...
#  #################### [100%] [287.85s]
# Processed samples: 176000
# Mean performance:
# M0 - Accuracy     : 0.9295
# M0 - Kappa        : 0.8343
# M0 - F1 score: 0.9492

# %%
mdl = DynamicWeightedMajorityClassifier()
evaluator = EvaluatePrequential(show_plot=False, 
                                pretrain_size=pretrain_size, 
                                batch_size=batch_size, 
                                metrics=metrics, 
                                max_samples=max_samples,
                                output_file=output_path + 'output_dwm.csv')
mdl = evaluator.evaluate(stream=stream, model=mdl)
# Out:
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 2000 sample(s).
# Evaluating...
#  #################### [100%] [549.10s]
# Processed samples: 176000
# Mean performance:
# M0 - Accuracy     : 0.8113
# M0 - Kappa        : 0.5909
# M0 - F1 score: 0.8534

# %%
mdl = OzaBaggingClassifier(base_estimator=HoeffdingAdaptiveTreeClassifier())
evaluator = EvaluatePrequential(show_plot=False, 
                                pretrain_size=pretrain_size, 
                                batch_size=batch_size, 
                                metrics=metrics, 
                                max_samples=max_samples,
                                output_file=output_path + 'output_obag.csv')
mdl = evaluator.evaluate(stream=stream, model=mdl)
# Out:
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 2000 sample(s).
# Evaluating...
#  #################### [100%] [3187.26s]
# Processed samples: 176000
# Mean performance:
# M0 - Accuracy     : 0.9354
# M0 - Kappa        : 0.8458
# M0 - F1 score: 0.9540

# %%
mdl = LearnPPNSEClassifier(base_estimator=HoeffdingAdaptiveTreeClassifier())
evaluator = EvaluatePrequential(show_plot=False, 
                                pretrain_size=pretrain_size, 
                                batch_size=batch_size, 
                                metrics=metrics, 
                                max_samples=max_samples,
                                output_file=output_path + 'output_nse.csv')
mdl = evaluator.evaluate(stream=stream, model=mdl)
# Out:
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 2000 sample(s).
# Evaluating...

# %%
df_ht = pd.read_csv(output_path + 'output_ht.csv', comment='#')
df_hta = pd.read_csv(output_path + 'output_hta.csv', comment='#')
df_dwm = pd.read_csv(output_path + 'output_dwm.csv', comment='#')
df_bag = pd.read_csv(output_path + 'output_obag.csv', comment='#')
df_nse = pd.read_csv(output_path + 'output_nse.csv', comment='#')

plt.figure()
plt.plot(df_ht['id'], df_ht['mean_acc_[M0]'], color='r', label='HT')
plt.plot(df_hta['id'], df_hta['mean_acc_[M0]'], color='b', label='HTA')
plt.plot(df_dwm['id'], df_dwm['mean_acc_[M0]'], color='k', label='DWM')
plt.plot(df_bag['id'], df_bag['mean_acc_[M0]'], color='m', label='Obag')
plt.plot(df_nse['id'], df_nse['mean_acc_[M0]'], color='c', label='L++')
plt.legend()
plt.xlabel('Sample Number')
plt.ylabel('Accuracy')
plt.savefig(output_path + 'online_accuracy.pdf')

# %%
plt.figure()
plt.plot(df_ht['id'], df_ht['mean_kappa_[M0]'], color='r', label='HT')
plt.plot(df_hta['id'], df_hta['mean_kappa_[M0]'], color='b', label='HTA')
plt.plot(df_dwm['id'], df_dwm['mean_kappa_[M0]'], color='k', label='DWM')
plt.plot(df_bag['id'], df_bag['mean_kappa_[M0]'], color='m', label='Obag')
plt.plot(df_nse['id'], df_nse['mean_kappa_[M0]'], color='c', label='L++')

plt.legend()
plt.xlabel('Sample Number')
plt.ylabel('Kappa')
plt.savefig(output_path + 'online_kappa.pdf')

# %%
plt.figure()
plt.plot(df_ht['id'], df_ht['mean_f1_[M0]'], color='r', label='HT')
plt.plot(df_hta['id'], df_hta['mean_f1_[M0]'], color='b', label='HTA')
plt.plot(df_dwm['id'], df_dwm['mean_f1_[M0]'], color='k', label='DWM')
plt.plot(df_bag['id'], df_bag['mean_f1_[M0]'], color='m', label='Obag')
plt.plot(df_nse['id'], df_nse['mean_f1_[M0]'], color='c', label='L++')

plt.legend()
plt.xlabel('Sample Number')
plt.ylabel('F1-Score')
plt.savefig(output_path + 'online_f2.pdf')
